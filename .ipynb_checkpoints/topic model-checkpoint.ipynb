# %%
import pandas as pd
import os
#https://betterprogramming.pub/how-to-scrape-tweets-with-snscrape-90124ed006af
#https://github.com/JustAnotherArchivist/snscrape

# %%
def download_tweets(user, num_tweets=100):
    os.system("snscrape --jsonl --max-results {num_tweets} twitter-search 'from:{user}'> tweets\\{user}-{num_tweets}.json".format(user=user, num_tweets=num_tweets))
#download_tweets(user="ZelenskyyUa", num_tweets=1000)
download_tweets(user="FedorovMykhailo", num_tweets=1000)

# %%
def read_tweets(user):
    # Reads the json generated from the CLI commands above and creates a pandas dataframe
    tweets_df = pd.read_json("tweets\\{user}.json".format(user=user), lines=True)
    print(tweets_df.columns)
    print(len(tweets_df))
    long_sentence = ""
    for row in range(len(tweets_df)):
        long_sentence += tweets_df.iloc[row].content
        if tweets_df.iloc[row].hashtags is not None:
            print(tweets_df.iloc[row])
        # print()
    # for row in range(len(tweets_df)):
    #     print(tweets_df[row].content)
    return long_sentence

tweets_df = pd.read_json("tweets\\{user}-1000.json".format(user="ZelenskyyUa"), lines=True)
print(tweets_df.columns)
print(tweets_df.head())
print(tweets_df.iloc[1])
# Out:
# Index(['_type', 'url', 'date', 'content', 'renderedContent', 'id', 'user',
#        'replyCount', 'retweetCount', 'likeCount', 'quoteCount',
#        'conversationId', 'lang', 'source', 'sourceUrl', 'sourceLabel',
#        'outlinks', 'tcooutlinks', 'media', 'retweetedTweet', 'quotedTweet',
#        'inReplyToTweetId', 'inReplyToUser', 'mentionedUsers', 'coordinates',
#        'place', 'hashtags', 'cashtags'],
#       dtype='object')
#                             _type  \
# 0  snscrape.modules.twitter.Tweet
# 1  snscrape.modules.twitter.Tweet
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/ZelenskyyUa/status/1584999...
# 1  https://twitter.com/ZelenskyyUa/status/1584999...
# 2  https://twitter.com/ZelenskyyUa/status/1584866...
# 3  https://twitter.com/ZelenskyyUa/status/1584866...
# 4  https://twitter.com/ZelenskyyUa/status/1584208...
#
#                        date  \
# 0 2022-10-25 20:04:51+00:00
# 1 2022-10-25 20:04:45+00:00
# 2 2022-10-25 11:15:34+00:00
# 3 2022-10-25 11:15:29+00:00
# 4 2022-10-23 15:40:38+00:00
#
#                                              content  \
# 0  In an excellent conversation with @RishiSunak ...
# 1  Під час чудової розмови з @RishiSunak домовили...
# 2  Congratulations to @RishiSunak on taking offic...
# 3  Вітаю @RishiSunak зі вступом на посаду Прем'єр...
# 4  Continued dialogue with IMF Managing Director ...
#
#                                      renderedContent                   id  \
# 0  In an excellent conversation with @RishiSunak ...  1584999451948888064
# 1  Під час чудової розмови з @RishiSunak домовили...  1584999427093106688
# 2  Congratulations to @RishiSunak on taking offic...  1584866250597228545
# 3  Вітаю @RishiSunak зі вступом на посаду Прем'єр...  1584866230544257024
# 4  Continued dialogue with IMF Managing Director ...  1584208182205108224
#
#                                                 user  replyCount  \
# 0  {'_type': 'snscrape.modules.twitter.User', 'us...        2150
# 1  {'_type': 'snscrape.modules.twitter.User', 'us...         353
# 2  {'_type': 'snscrape.modules.twitter.User', 'us...        1712
# 3  {'_type': 'snscrape.modules.twitter.User', 'us...         227
# 4  {'_type': 'snscrape.modules.twitter.User', 'us...        1209
#
#    retweetCount  likeCount  ...  media  retweetedTweet quotedTweet  \
# 0          4021      37044  ...   None             NaN        None
# 1           787       7909  ...   None             NaN        None
# 2          2643      31220  ...   None             NaN        None
# 3           666       7392  ...   None             NaN        None
# 4          1756      12428  ...   None             NaN        None
#
#   inReplyToTweetId inReplyToUser  \
# 0              NaN          None
# 1              NaN          None
# 2              NaN          None
# 3              NaN          None
# 4              NaN          None
#
#                                       mentionedUsers coordinates place  \
# 0  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 1  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 2  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 3  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 4  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
#
#   hashtags  cashtags
# 0     None       NaN
# 1     None       NaN
# 2     None       NaN
# 3     None       NaN
# 4     None       NaN
#
# [5 rows x 28 columns]
# _type                                  snscrape.modules.twitter.Tweet
# url                 https://twitter.com/ZelenskyyUa/status/1584999...
# date                                        2022-10-25 20:04:45+00:00
# content             Під час чудової розмови з @RishiSunak домовили...
# renderedContent     Під час чудової розмови з @RishiSunak домовили...
# id                                                1584999427093106688
# user                {'_type': 'snscrape.modules.twitter.User', 'us...
# replyCount                                                        353
# retweetCount                                                      787
# likeCount                                                        7909
# quoteCount                                                         20
# conversationId                                    1584999427093106688
# lang                                                               uk
# source              <a href="https://mobile.twitter.com" rel="nofo...
# sourceUrl                                  https://mobile.twitter.com
# sourceLabel                                           Twitter Web App
# outlinks                                                         None
# tcooutlinks                                                      None
# media                                                            None
# retweetedTweet                                                    NaN
# quotedTweet                                                      None
# inReplyToTweetId                                                  NaN
# inReplyToUser                                                    None
# mentionedUsers      [{'_type': 'snscrape.modules.twitter.User', 'u...
# coordinates                                                       NaN
# place                                                             NaN
# hashtags                                                         None
# cashtags                                                          NaN
# Name: 1, dtype: object

# %%
# all tweets come from the iphone app or the twitter web app mobile.twitter.com
print(set(tweets_df["sourceLabel"]))
web = tweets_df.loc[tweets_df['sourceLabel'] == "Twitter Web App"]
iphone = tweets_df.loc[tweets_df['sourceLabel'] == "Twitter for iPhone"]
print(web.head())
print(iphone.head())
# Out:
# {'Twitter Web App', 'Twitter for iPhone'}
#                              _type  \
# 0   snscrape.modules.twitter.Tweet
# 1   snscrape.modules.twitter.Tweet
# 8   snscrape.modules.twitter.Tweet
# 9   snscrape.modules.twitter.Tweet
# 12  snscrape.modules.twitter.Tweet
#
#                                                   url  \
# 0   https://twitter.com/ZelenskyyUa/status/1584999...
# 1   https://twitter.com/ZelenskyyUa/status/1584999...
# 8   https://twitter.com/ZelenskyyUa/status/1583053...
# 9   https://twitter.com/ZelenskyyUa/status/1583053...
# 12  https://twitter.com/ZelenskyyUa/status/1582766...
#
#                         date  \
# 0  2022-10-25 20:04:51+00:00
# 1  2022-10-25 20:04:45+00:00
# 8  2022-10-20 11:11:41+00:00
# 9  2022-10-20 11:11:37+00:00
# 12 2022-10-19 16:11:18+00:00
#
#                                               content  \
# 0   In an excellent conversation with @RishiSunak ...
# 1   Під час чудової розмови з @RishiSunak домовили...
# 8   Had a substantive &amp; productive call with 🇩...
# 9   Провів предметну й продуктивну розмову з Прези...
# 12  Grateful to @Europarl_EN, @EP_President for aw...
#
#                                       renderedContent                   id  \
# 0   In an excellent conversation with @RishiSunak ...  1584999451948888064
# 1   Під час чудової розмови з @RishiSunak домовили...  1584999427093106688
# 8   Had a substantive &amp; productive call with 🇩...  1583053335057563649
# 9   Провів предметну й продуктивну розмову з Прези...  1583053318003523584
# 12  Grateful to @Europarl_EN, @EP_President for aw...  1582766347032723458
#
#                                                  user  replyCount  \
# 0   {'_type': 'snscrape.modules.twitter.User', 'us...        2150
# 1   {'_type': 'snscrape.modules.twitter.User', 'us...         353
# 8   {'_type': 'snscrape.modules.twitter.User', 'us...        1435
# 9   {'_type': 'snscrape.modules.twitter.User', 'us...         416
# 12  {'_type': 'snscrape.modules.twitter.User', 'us...         885
#
#     retweetCount  likeCount  ...  media  retweetedTweet quotedTweet  \
# 0           4021      37044  ...   None             NaN        None
# 1            787       7909  ...   None             NaN        None
# 8           2402      18292  ...   None             NaN        None
# 9            693       6434  ...   None             NaN        None
# 12          1989      11795  ...   None             NaN        None
#
#    inReplyToTweetId inReplyToUser  \
# 0               NaN          None
# 1               NaN          None
# 8               NaN          None
# 9               NaN          None
# 12              NaN          None
#
#                                        mentionedUsers coordinates place  \
# 0   [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 1   [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 8                                                None         NaN   NaN
# 9                                                None         NaN   NaN
# 12  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
#
#    hashtags  cashtags
# 0      None       NaN
# 1      None       NaN
# 8    [IRIS]       NaN
# 9    [IRIS]       NaN
# 12     None       NaN
#
# [5 rows x 28 columns]
#                             _type  \
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
# 5  snscrape.modules.twitter.Tweet
# 6  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 2  https://twitter.com/ZelenskyyUa/status/1584866...
# 3  https://twitter.com/ZelenskyyUa/status/1584866...
# 4  https://twitter.com/ZelenskyyUa/status/1584208...
# 5  https://twitter.com/ZelenskyyUa/status/1584208...
# 6  https://twitter.com/ZelenskyyUa/status/1583780...
#
#                        date  \
# 2 2022-10-25 11:15:34+00:00
# 3 2022-10-25 11:15:29+00:00
# 4 2022-10-23 15:40:38+00:00
# 5 2022-10-23 15:40:34+00:00
# 6 2022-10-22 11:21:12+00:00
#
#                                              content  \
# 2  Congratulations to @RishiSunak on taking offic...
# 3  Вітаю @RishiSunak зі вступом на посаду Прем'єр...
# 4  Continued dialogue with IMF Managing Director ...
# 5  Продовжив діалог із директоркою МВФ @KGeorgiev...
# 6  My congratulations to @GiorgiaMeloni, the firs...
#
#                                      renderedContent                   id  \
# 2  Congratulations to @RishiSunak on taking offic...  1584866250597228545
# 3  Вітаю @RishiSunak зі вступом на посаду Прем'єр...  1584866230544257024
# 4  Continued dialogue with IMF Managing Director ...  1584208182205108224
# 5  Продовжив діалог із директоркою МВФ @KGeorgiev...  1584208163888582657
# 6  My congratulations to @GiorgiaMeloni, the firs...  1583780507547885568
#
#                                                 user  replyCount  \
# 2  {'_type': 'snscrape.modules.twitter.User', 'us...        1712
# 3  {'_type': 'snscrape.modules.twitter.User', 'us...         227
# 4  {'_type': 'snscrape.modules.twitter.User', 'us...        1209
# 5  {'_type': 'snscrape.modules.twitter.User', 'us...         383
# 6  {'_type': 'snscrape.modules.twitter.User', 'us...        1927
#
#    retweetCount  likeCount  ...  media  retweetedTweet quotedTweet  \
# 2          2643      31220  ...   None             NaN        None
# 3           666       7392  ...   None             NaN        None
# 4          1756      12428  ...   None             NaN        None
# 5           673       6015  ...   None             NaN        None
# 6          2767      29115  ...   None             NaN        None
#
#   inReplyToTweetId inReplyToUser  \
# 2              NaN          None
# 3              NaN          None
# 4              NaN          None
# 5              NaN          None
# 6              NaN          None
#
#                                       mentionedUsers coordinates place  \
# 2  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 3  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 4  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 5  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 6  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
#
#   hashtags  cashtags
# 2     None       NaN
# 3     None       NaN
# 4     None       NaN
# 5     None       NaN
# 6     None       NaN
#
# [5 rows x 28 columns]

# %%
# import nltk
# nltk.download('nps_chat')
# nltk.download('webtext')
from nltk.book import FreqDist
from nltk.tokenize import word_tokenize
import re
big_string = " ".join(web.content)
big_string = big_string.lower()
big_string = re.sub("[^\w\s]", "", big_string)
all_web_content = word_tokenize(big_string) # turn the rows into one string
# print(all_web_content)
# print("\n\n\n")

from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
all_web_content = [i for i in all_web_content if i not in stop_words]


freqDist = FreqDist(all_web_content)
freqDist.plot(10)

# from googletrans import Translator
# translator = Translator()
# translator.translate('Продовжив діалог із директоркою МВФ @KGeorgiev', src='uk', dest='en')
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
# Import the wordcloud library
from wordcloud import WordCloud# Join the different processed titles together.

long_string = read_tweets("ZelenskyyUa")

wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')# Generate a word cloud
wordcloud.generate(long_string)# Visualize the word cloud
wordcloud.to_image()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-8a6277b900f4> in <module>
#       1 # Import the wordcloud library
# ----> 2 from wordcloud import WordCloud# Join the different processed titles together.
#       3
#       4 long_string = read_tweets("ZelenskyyUa")
#       5
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
import gensim
from gensim.utils import simple_preprocess
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])
def sent_to_words(sentences):
    for sentence in sentences:
        # deacc=True removes punctuations
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))
def remove_stopwords(doc):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words]]
# data = papers.paper_text_processed.values.tolist()
# data_words = list(sent_to_words(data))
data_words = long_string.split(" ")
print(data_words)
# remove stop words
data_words = remove_stopwords(data_words)
print(data_words[:1][0][:30])

import gensim.corpora as corpora# Create Dictionary
id2word = corpora.Dictionary(data_words)# Create Corpus
texts = data_words# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]# View
print(corpus[:1][0][:30])
# Out:
# ['\nTopic', 'model\nFrom', 'Wikipedia,', 'the', 'free', 'encyclopedia\nJump', 'to', 'navigation\nJump', 'to', 'search\n\t\nThis', 'article', 'uses', 'bare', 'URLs,', 'which', 'are', 'uninformative', 'and', 'vulnerable', 'to', 'link', 'rot.', 'Please', 'consider', 'converting', 'them', 'to', 'full', 'citations', 'to', 'ensure', 'the', 'article', 'remains', 'verifiable', 'and', 'maintains', 'a', 'consistent', 'citation', 'style.', 'Several', 'templates', 'and', 'tools', 'are', 'available', 'to', 'assist', 'in', 'formatting,', 'such', 'as', 'Reflinks', '(documentation),', 'reFill', '(documentation)', 'and', 'Citation', 'bot', '(documentation).', '(September', '2022)', '(Learn', 'how', 'and', 'when', 'to', 'remove', 'this', 'template', 'message)\n\nIn', 'statistics', 'and', 'natural', 'language', 'processing,', 'a', 'topic', 'model', 'is', 'a', 'type', 'of', 'statistical', 'model', 'for', 'discovering', 'the', 'abstract', '"topics"', 'that', 'occur', 'in', 'a', 'collection', 'of', 'documents.', 'Topic', 'modeling', 'is', 'a', 'frequently', 'used', 'text-mining', 'tool', 'for', 'discovery', 'of', 'hidden', 'semantic', 'structures', 'in', 'a', 'text', 'body.', 'Intuitively,', 'given', 'that', 'a', 'document', 'is', 'about', 'a', 'particular', 'topic,', 'one', 'would', 'expect', 'particular', 'words', 'to', 'appear', 'in', 'the', 'document', 'more', 'or', 'less', 'frequently:', '"dog"', 'and', '"bone"', 'will', 'appear', 'more', 'often', 'in', 'documents', 'about', 'dogs,', '"cat"', 'and', '"meow"', 'will', 'appear', 'in', 'documents', 'about', 'cats,', 'and', '"the"', 'and', '"is"', 'will', 'appear', 'approximately', 'equally', 'in', 'both.', 'A', 'document', 'typically', 'concerns', 'multiple', 'topics', 'in', 'different', 'proportions;', 'thus,', 'in', 'a', 'document', 'that', 'is', '10%', 'about', 'cats', 'and', '90%', 'about', 'dogs,', 'there', 'would', 'probably', 'be', 'about', '9', 'times', 'more', 'dog', 'words', 'than', 'cat', 'words.', 'The', '"topics"', 'produced', 'by', 'topic', 'modeling', 'techniques', 'are', 'clusters', 'of', 'similar', 'words.', 'A', 'topic', 'model', 'captures', 'this', 'intuition', 'in', 'a', 'mathematical', 'framework,', 'which', 'allows', 'examining', 'a', 'set', 'of', 'documents', 'and', 'discovering,', 'based', 'on', 'the', 'statistics', 'of', 'the', 'words', 'in', 'each,', 'what', 'the', 'topics', 'might', 'be', 'and', 'what', 'each', "document's", 'balance', 'of', 'topics', 'is.\n\nTopic', 'models', 'are', 'also', 'referred', 'to', 'as', 'probabilistic', 'topic', 'models,', 'which', 'refers', 'to', 'statistical', 'algorithms', 'for', 'discovering', 'the', 'latent', 'semantic', 'structures', 'of', 'an', 'extensive', 'text', 'body.', 'In', 'the', 'age', 'of', 'information,', 'the', 'amount', 'of', 'the', 'written', 'material', 'we', 'encounter', 'each', 'day', 'is', 'simply', 'beyond', 'our', 'processing', 'capacity.', 'Topic', 'models', 'can', 'help', 'to', 'organize', 'and', 'offer', 'insights', 'for', 'us', 'to', 'understand', 'large', 'collections', 'of', 'unstructured', 'text', 'bodies.', 'Originally', 'developed', 'as', 'a', 'text-mining', 'tool,', 'topic', 'models', 'have', 'been', 'used', 'to', 'detect', 'instructive', 'structures', 'in', 'data', 'such', 'as', 'genetic', 'information,', 'images,', 'and', 'networks.', 'They', 'also', 'have', 'applications', 'in', 'other', 'fields', 'such', 'as', 'bioinformatics[1]', 'and', 'computer', 'vision.[2]\nContents\n\n', '', '', '', '1', 'History\n', '', '', '', '2', 'Topic', 'models', 'for', 'context', 'information\n', '', '', '', '3', 'Algorithms\n', '', '', '', '4', 'Topic', 'models', 'for', 'quantitative', 'biomedicine\n', '', '', '', '5', 'See', 'also\n', '', '', '', '6', 'References\n', '', '', '', '7', 'Further', 'reading\n', '', '', '', '8', 'External', 'links\n\nHistory\n\nAn', 'early', 'topic', 'model', 'was', 'described', 'by', 'Papadimitriou,', 'Raghavan,', 'Tamaki', 'and', 'Vempala', 'in', '1998.[3]', 'Another', 'one,', 'called', 'pr ...
# ['ntopic', 'model', 'nfrom', 'wikipedia', 'free', 'encyclopedia', 'njump', 'navigation', 'njump', 'search', 'nthis', 'article', 'uses', 'bare', 'urls', 'uninformative', 'vulnerable', 'link', 'rot', 'please', 'consider', 'converting', 'full', 'citations', 'ensure', 'article', 'remains', 'verifiable', 'maintains', 'consistent']
# [(0, 1), (1, 1), (2, 1), (3, 1), (4, 1), (5, 1), (6, 3), (7, 1), (8, 1), (9, 1), (10, 1), (11, 1), (12, 1), (13, 2), (14, 1), (15, 1), (16, 5), (17, 1), (18, 5), (19, 1), (20, 4), (21, 1), (22, 6), (23, 1), (24, 1), (25, 4), (26, 1), (27, 1), (28, 8), (29, 1)]
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\adder\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print("UP TO MODEL")
from pprint import pprint
# number of topics
num_topics = 10
# Build LDA model
lda_model = gensim.models.LdaModel(corpus=corpus, id2word=id2word, num_topics=num_topics)
# lda_model = gensim.models.LdaMulticore(corpus=corpus,
#                                        id2word=id2word,
#                                        num_topics=num_topics, workers=1)# Print the Keyword in the 10 topics
pprint(lda_model.print_topics())
#doc_lda = lda_model[corpus]
# Out:
# UP TO MODEL
# [(0,
#   '0.015*"topic" + 0.009*"models" + 0.007*"topics" + 0.007*"model" + '
#   '0.006*"modeling" + 0.006*"journal" + 0.006*"latent" + 0.005*"documents" + '
#   '0.005*"information" + 0.004*"document"'),
#  (1,
#   '0.031*"topic" + 0.012*"modeling" + 0.012*"models" + 0.011*"model" + '
#   '0.010*"topics" + 0.008*"journal" + 0.007*"documents" + 0.007*"doi" + '
#   '0.007*"latent" + 0.006*"document"'),
#  (2,
#   '0.020*"topic" + 0.011*"modeling" + 0.009*"topics" + 0.007*"doi" + '
#   '0.007*"information" + 0.007*"models" + 0.006*"model" + 0.006*"pdf" + '
#   '0.006*"latent" + 0.005*"documents"'),
#  (3,
#   '0.033*"topic" + 0.017*"models" + 0.012*"modeling" + 0.011*"topics" + '
#   '0.009*"information" + 0.008*"doi" + 0.008*"latent" + 0.007*"documents" + '
#   '0.007*"model" + 0.007*"document"'),
#  (4,
#   '0.032*"topic" + 0.015*"models" + 0.011*"modeling" + 0.011*"topics" + '
#   '0.010*"latent" + 0.010*"model" + 0.009*"information" + 0.007*"documents" + '
#   '0.007*"doi" + 0.006*"journal"'),
#  (5,
#   '0.016*"topic" + 0.009*"models" + 0.009*"topics" + 0.008*"modeling" + '
#   '0.008*"model" + 0.007*"information" + 0.006*"latent" + 0.006*"journal" + '
#   '0.005*"doi" + 0.005*"document"'),
#  (6,
#   '0.027*"topic" + 0.015*"models" + 0.012*"topics" + 0.011*"modeling" + '
#   '0.009*"model" + 0.009*"information" + 0.009*"doi" + 0.008*"latent" + '
#   '0.007*"pdf" + 0.006*"documents"'),
#  (7,
#   '0.023*"topic" + 0.012*"models" + 0.010*"topics" + 0.009*"information" + '
#   '0.009*"modeling" + 0.009*"model" + 0.007*"journal" + 0.007*"doi" + '
#   '0.006*"latent" + 0.006*"used"'),
#  (8,
#   '0.036*"topic" + 0.013*"models" + 0.011*"modeling" + 0.010*"model" + '
#   '0.009*"topics" + 0.009*"latent" + 0.009*"information" + 0.007*"doi" + '
#   '0.006*"documents" + 0.006*"document"'),
#  (9,
#   '0.026*"topic" + 0.013*"models" + 0.011*"topics" + 0.010*"modeling" + '
#   '0.009*"model" + 0.008*"documents" + 0.008*"information" + 0.007*"doi" + '
#   '0.006*"latent" + 0.006*"journal"')]

# %%
print("up to visualize")
import os
import pyLDAvis.gensim_models
import pickle
import pyLDAvis# Visualize the topics
pyLDAvis.enable_notebook()
LDAvis_data_filepath = os.path.join("C:\\Users\\adder\\Documents\\Minerva\\CCP Ukraine\\" + str(num_topics))# # this is a bit time consuming - make the if statement True
# # if you want to execute visualization prep yourself
print(LDAvis_data_filepath)
LDAvis_prepared = pyLDAvis.gensim_models.prepare(lda_model, corpus, id2word)
with open(LDAvis_data_filepath, 'wb') as f:
    pickle.dump(LDAvis_prepared, f)# load the pre-prepared pyLDAvis data from disk

with open(LDAvis_data_filepath, 'rb') as f:
    LDAvis_prepared = pickle.load(f)
    pyLDAvis.save_html(LDAvis_prepared, str(num_topics) +'.html')
    LDAvis_prepared
# Out:
# up to visualize
# C:\Users\adder\Documents\Minerva\CCP Ukraine\10
# C:\Python310\lib\site-packages\pyLDAvis\_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   by='saliency', ascending=False).head(R).drop('saliency', 1)
